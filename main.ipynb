# %%
import pandas as pd

# %%
df = pd.read_csv("final_emailphone_personal.csv")

# %%
df
# Out:
#                      name                                              phone
# 0          heynel axelevi                                    ['13462128871']  \
# 1           arran gillies                                   ['447447338812']
# 2            don gennrich                      ['7154532131', '17156121991']
# 3               kay patel                       ['3106716017', '9038779227']
# 4        brittany couture                                    ['18054529478']
# ...                   ...                                                ...
# 1048570        sion stone                                    ['19198421156']
# 1048571     douglas silva                                  ['5511962536679']
# 1048572    jason maulding                                     ['6303055347']
# 1048573      thomas riker  ['1-501-366-8903', '5018825529', '1-501-288-22...
# 1048574    carl hostetler               ['1-530-274-0257', '1-707-360-8549']
#
#                                                linkedinurl
# 0        https://www.linkedin.com/in/heynel-axelevi-9a4...  \
# 1        https://www.linkedin.com/in/arran-gillies-8917...
# 2         https://www.linkedin.com/in/don-gennrich-8712854
# 3            https://www.linkedin.com/in/kay-patel-88b1902
# 4        https://www.linkedin.com/in/brittany-couture-b...
# ...                                                    ...
# 1048570     https://www.linkedin.com/in/sion-stone-3330a89
# 1048571  https://www.linkedin.com/in/douglas-silva-0311...
# 1048572  https://www.linkedin.com/in/jason-maulding-660...
# 1048573  https://www.linkedin.com/in/thomas-riker-90506716
# 1048574  https://www.linkedin.com/in/carl-hostetler-b57...
#
#                                lid
# 0          heynel-axelevi-9a4b4637  \
# 1           arran-gillies-89172923
# 2             don-gennrich-8712854
# 3                kay-patel-88b1902
# 4        brittany-couture-b2673448
# ...                            ...
# 1048570         sion-stone-3330a89
# 1048571     douglas-silva-0311b642
# 1048572    jason-maulding-660b2133
# 1048573      thomas-riker-90506716
# 1048574    carl-hostetler-b579702a
#
#                                                 location
# 0        washington, district of columbia, united states  \
# 1                                         united kingdom
# 2                     tomahawk, wisconsin, united states
# 3                   hampshire, hampshire, united kingdom
# 4                   boston, massachusetts, united states
# ...                                                  ...
# 1048570           raleigh, north carolina, united states
# 1048571                     sao paulo, sao paulo, brazil
# 1048572                 chicago, illinois, united states
# 1048573             little rock, arkansas, united states
# 1048574                                    united states
#
#                                                      email
# 0                                 heynel_axelevi@yahoo.com
# 1                                    narra1985@hotmail.com
# 2                                    dongennrich@gmail.com
# 3                                    kay_patel@hotmail.com
# 4                                   run5soccer@hotmail.com
# ...                                                    ...
# 1048570                             sioncarterus@yahoo.com
# 1048571                           douglascrazy@hotmail.com
# 1048572                                  npd7652@gmail.com
# 1048573  nitro864@msn.com, nitro864@netscape.net, riker...
# 1048574                           carl.hostetler@gmail.com
#
# [1048575 rows x 6 columns]

# %%
countries = ['Austria', 'Belgium', 
             'Bulgaria', 'Croatia', 
             'Cyprus', 'Czechia', 'Denmark', 
             'Estonia', 'Finland', 'France', 
             'Germany', 'Greece', 'Hungary', 
             'Ireland', 'Italy', 'Latvia', 
             'Lithuania', 'Luxembourg', 'Malta', 
             'Netherlands', 'Poland', 'Portugal', 
             'Romania', 'Slovakia', 'Slovenia', 
             'Spain', 'Sweden']

# %%
new_list = []
for country in countries:
    new_list.append(country.lower())

# %%
new_list
# Out:
# ['austria',
#  'belgium',
#  'bulgaria',
#  'croatia',
#  'cyprus',
#  'czechia',
#  'denmark',
#  'estonia',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hungary',
#  'ireland',
#  'italy',
#  'latvia',
#  'lithuania',
#  'luxembourg',
#  'malta',
#  'netherlands',
#  'poland',
#  'portugal',
#  'romania',
#  'slovakia',
#  'slovenia',
#  'spain',
#  'sweden']

# %%
df = df[~df['location'].isin(new_list)]

# %%
df
# Out:
#                      name                                              phone
# 0          heynel axelevi                                    ['13462128871']  \
# 1           arran gillies                                   ['447447338812']
# 2            don gennrich                      ['7154532131', '17156121991']
# 3               kay patel                       ['3106716017', '9038779227']
# 4        brittany couture                                    ['18054529478']
# ...                   ...                                                ...
# 1048570        sion stone                                    ['19198421156']
# 1048571     douglas silva                                  ['5511962536679']
# 1048572    jason maulding                                     ['6303055347']
# 1048573      thomas riker  ['1-501-366-8903', '5018825529', '1-501-288-22...
# 1048574    carl hostetler               ['1-530-274-0257', '1-707-360-8549']
#
#                                                linkedinurl
# 0        https://www.linkedin.com/in/heynel-axelevi-9a4...  \
# 1        https://www.linkedin.com/in/arran-gillies-8917...
# 2         https://www.linkedin.com/in/don-gennrich-8712854
# 3            https://www.linkedin.com/in/kay-patel-88b1902
# 4        https://www.linkedin.com/in/brittany-couture-b...
# ...                                                    ...
# 1048570     https://www.linkedin.com/in/sion-stone-3330a89
# 1048571  https://www.linkedin.com/in/douglas-silva-0311...
# 1048572  https://www.linkedin.com/in/jason-maulding-660...
# 1048573  https://www.linkedin.com/in/thomas-riker-90506716
# 1048574  https://www.linkedin.com/in/carl-hostetler-b57...
#
#                                lid
# 0          heynel-axelevi-9a4b4637  \
# 1           arran-gillies-89172923
# 2             don-gennrich-8712854
# 3                kay-patel-88b1902
# 4        brittany-couture-b2673448
# ...                            ...
# 1048570         sion-stone-3330a89
# 1048571     douglas-silva-0311b642
# 1048572    jason-maulding-660b2133
# 1048573      thomas-riker-90506716
# 1048574    carl-hostetler-b579702a
#
#                                                 location
# 0        washington, district of columbia, united states  \
# 1                                         united kingdom
# 2                     tomahawk, wisconsin, united states
# 3                   hampshire, hampshire, united kingdom
# 4                   boston, massachusetts, united states
# ...                                                  ...
# 1048570           raleigh, north carolina, united states
# 1048571                     sao paulo, sao paulo, brazil
# 1048572                 chicago, illinois, united states
# 1048573             little rock, arkansas, united states
# 1048574                                    united states
#
#                                                      email
# 0                                 heynel_axelevi@yahoo.com
# 1                                    narra1985@hotmail.com
# 2                                    dongennrich@gmail.com
# 3                                    kay_patel@hotmail.com
# 4                                   run5soccer@hotmail.com
# ...                                                    ...
# 1048570                             sioncarterus@yahoo.com
# 1048571                           douglascrazy@hotmail.com
# 1048572                                  npd7652@gmail.com
# 1048573  nitro864@msn.com, nitro864@netscape.net, riker...
# 1048574                           carl.hostetler@gmail.com
#
# [1046654 rows x 6 columns]
